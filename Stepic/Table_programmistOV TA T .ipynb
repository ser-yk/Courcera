# %%
# char = int(input())
#
#
#
# def create_table(width, data, color, i):
#     while i <= 1000:
#         if i < width:
#             print('\033[{}m {}'.format(color, data))
#             i += 1
#             print(i)
#             return i
#         elif i == width:
#             print('\033[{}m {}'.format(color, data))
#             i += 1
#             return i
#         else:
#
#             if i > 1000:
#                 i = 0
#                 print('Неверные параметры', i)
#
#

char = -1
i = 0
while char < 1000:
    char += 1
    if (char % 10 == 1 and char % 100 != 11):
        if char % 20 == 0:
            print('\n', '\033[31m |{:<}т'.format(char), end = '')
        else:
            print('\033[31m |{:<}т'.format(char), end = '')



    elif (char % 10 in [2, 3, 4] and char % 100 not in [11, 12, 13, 14]):
        
        if char % 20 == 0:
            print('\n', '\033[32m |{:<}а'.format(char), end = '')
          
        else:
            print('\033[32m |{:<}а'.format(char), end = '')



    else:
        if char % 20 == 0:
            print('\n', '\033[33m |{:<}в'.format(char), end = '')
        else:
            print('\033[33m |{:<}в'.format(char), end = '')





# print((100 < char and ((char % 10 == 2) or (char % 10 == 3) or (char % 10 == 4))))
# Out:
#   |0в |1т |2а |3а |4а |5в |6в |7в |8в |9в |10в |11в |12в |13в |14в |15в |16в |17в |18в |19в
#   |20в |21т |22а |23а |24а |25в |26в |27в |28в |29в |30в |31т |32а |33а |34а |35в |36в |37в |38в |39в
#   |40в |41т |42а |43а |44а |45в |46в |47в |48в |49в |50в |51т |52а |53а |54а |55в |56в |57в |58в |59в
#   |60в |61т |62а |63а |64а |65в |66в |67в |68в |69в |70в |71т |72а |73а |74а |75в |76в |77в |78в |79в
#   |80в |81т |82а |83а |84а |85в |86в |87в |88в |89в |90в |91т |92а |93а |94а |95в |96в |97в |98в |99в
#   |100в |101т |102а |103а |104а |105в |106в |107в |108в |109в |110в |111в |112в |113в |114в |115в |116в |117в |118в |119в
#   |120в |121т |122а |123а |124а |125в |126в |127в |128в |129в |130в |131т |132а |133а |134а |135в |136в |137в |138в |139в
#   |140в |141т |142а |143а |144а |145в |146в |147в |148в |149в |150в |151т |152а |153а |154а |155в |156в |157в |158в |159в
# ...
